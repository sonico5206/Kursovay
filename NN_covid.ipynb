# %%
import pandas as pd
import matplotlib.pyplot as plt

# Функция для построения одного графика
def plot_series(file_path, title, time_col='timestamp', value_col='value'):
    df = pd.read_csv(file_path)
    df.columns = [col.lower() for col in df.columns]  # Приведение к нижнему регистру
    df[time_col] = pd.to_datetime(df[time_col])
    plt.figure(figsize=(7, 4))
    plt.plot(pd.to_datetime(df[time_col]), df[value_col], color='steelblue')
    plt.title(title)
    plt.xlabel('Время')
    plt.ylabel('Значение')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('graf_COVID.png')
    plt.show()

# Построение каждого ряда по отдельности
plot_series('TIMES/covid_italy_time_series.csv', 'Ряд COVID (нестабильный тренд)')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.layers import Input

# 1. Загрузка данных из файла
file_path = "TIMES/covid_italy_time_series.csv"
df = pd.read_csv(file_path)

# Проверяем содержимое файла
print(df.head())

# Преобразование timestamp в формат datetime и установка индекса
df["timestamp"] = pd.to_datetime(df["timestamp"], format="%Y-%m-%d") # Указываем формат времени
df.set_index("timestamp", inplace=True)

# 2. Подготовка данных
# Ресемплинг данных, если необходимо (например, для равномерного временного ряда)
#df = df.resample("5min").mean() #Удаляем! Не нужен, данные дневные.

# Масштабирование значений в диапазон [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
df["value"] = scaler.fit_transform(df[["value"]])

# Создание входных (X) и выходных (y) последовательностей
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i : i + seq_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)

sequence_length = 30  # Длина входной последовательности, 30 дней. Учитываем месячный цикл.
data_values = df["value"].values
X, y = create_sequences(data_values, sequence_length)


test_size = 0.2  # 20% для тестового набора
test_split_idx = int(len(data_values) * (1 - test_size))

X_train, X_test = X[:test_split_idx], X[test_split_idx:]
y_train, y_test = y[:test_split_idx], y[test_split_idx:]


# Преобразование данных в 3D-формат для LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# 3. Построение модели LSTM
model = Sequential()
model.add(Input(shape=(sequence_length, 1)))  # Явно задаем вход
model.add(LSTM(50, activation="relu"))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mse")

# 4. Обучение модели
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# 5. Прогнозирование
y_pred = model.predict(X_test)

# Обратное масштабирование для оценки
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# Визуализация
plt.figure(figsize=(10, 6))
plt.plot(y_test, label="Истинные значения")
plt.plot(y_pred, label="Прогноз", linestyle="dashed")
plt.legend()
plt.title("Прогнозирование covid_italy_time_series.csv с использованием LSTM")
plt.savefig('progn_covid.png')
plt.show()

# Сохранение модели
model.save("lstm_model.keras")
# Out:
#     timestamp  value
# 0  2020-01-22      0
# 1  2020-01-23      0
# 2  2020-01-24      0
# 3  2020-01-25      0
# 4  2020-01-26      0
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.6817 - val_loss: 0.8916
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5026 - val_loss: 0.6284
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3307 - val_loss: 0.3490
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1830 - val_loss: 0.0797
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0420 - val_loss: 0.1959
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0535 - val_loss: 0.0060
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0099 - val_loss: 0.0138
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0208 - val_loss: 0.0109
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147 - val_loss: 3.9433e-05
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073 - val_loss: 0.0128
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088 - val_loss: 0.0092
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - val_loss: 7.6763e-04
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056 - val_loss: 6.9786e-06
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051 - val_loss: 6.4614e-04
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - val_loss: 8.6923e-04
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 9.8213e-04
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - val_loss: 8.4695e-04
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 7.5490e-04
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 7.1879e-04
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 7.0348e-04
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8389e-04 - val_loss: 7.0422e-04
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8126e-04 - val_loss: 4.7699e-04
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6299e-04 - val_loss: 3.0169e-04
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7380e-04 - val_loss: 4.3514e-04
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.0593e-04 - val_loss: 2.1412e-05
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5762e-04 - val_loss: 4.1982e-04
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2795e-04 - val_loss: 6.5257e-05
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4410e-04 - val_loss: 8.2188e-05
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5395e-04 - val_loss: 7.4837e-05
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4829e-04 - val_loss: 1.7609e-05
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1322e-05 - val_loss: 9.0944e-05
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7878e-05 - val_loss: 7.9664e-07
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5613e-05 - val_loss: 5.6962e-05
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5164e-05 - val_loss: 4.6532e-05
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3552e-05 - val_loss: 2.3151e-05
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8275e-05 - val_loss: 8.6158e-05
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4228e-05 - val_loss: 1.0214e-04
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3827e-05 - val_loss: 8.4104e-05
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8322e-05 - val_loss: 5.0076e-05
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4136e-05 - val_loss: 3.7767e-05
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1828e-05 - val_loss: 8.4233e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step

# %%
# Построение графика потерь (Loss)
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss', linestyle='-')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='-.')
plt.title("График потерь по эпохам covid_italy_time_series.csv")
plt.xlabel("Эпоха")
plt.ylabel("MSE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("loss_covid.png")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam

# Загрузка данных
df = pd.read_csv("TIMES/daily-min-temperatures.csv")
df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d")
df.set_index('timestamp', inplace=True)
#df = df.resample("5T").mean()  # Агрегация по 5 минутам - удаляем

# Нормализация данных
data_min = df['value'].min()
data_max = df['value'].max()
df['value'] = (df['value'] - data_min) / (data_max - data_min)

# Подготовка данных
sequence_length = 30 # Длина последовательности
data = df['value'].values
X, y = [], []

for i in range(len(data) - sequence_length):
    X.append(data[i:i + sequence_length])
    y.append(data[i + sequence_length])

X = np.array(X)
y = np.array(y)

# Разделение на обучающую и тестовую выборки
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Функция для создания модели
def create_model(layers_count, hidden_units, activation, use_dropout):
    model = Sequential()
    model.add(LSTM(hidden_units, activation=activation, input_shape=(sequence_length, 1), return_sequences=(layers_count > 1)))
    for _ in range(layers_count - 1):
        model.add(LSTM(hidden_units, activation=activation, return_sequences=False if _ == layers_count - 2 else True))
        if use_dropout:
            model.add(Dropout(0.2))  # Регуляризация Dropout
    model.add(Dense(1))  # Выходной слой
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse'])
    return model

# Экспериментальные настройки
experiments = [
    {"layers_count": 2, "hidden_units": 128, "activation": "relu", "use_dropout": False},
    {"layers_count": 5, "hidden_units": 128, "activation": "relu", "use_dropout": True},
    {"layers_count": 2, "hidden_units": 64, "activation": "tanh", "use_dropout": False},
    {"layers_count": 5, "hidden_units": 64, "activation": "tanh", "use_dropout": True},
]

results = []
best_scores = []

# Обучение моделей
for exp in experiments:
    print(f"Тренируем модель: {exp['layers_count']} слоя(ев), {exp['hidden_units']} нейронов, активация {exp['activation']}, Dropout: {exp['use_dropout']}...")
    model = create_model(exp["layers_count"], exp["hidden_units"], exp["activation"], exp["use_dropout"])
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        batch_size=32,
        epochs=20,
        verbose=1
    )
    results.append({
        "params": exp,
        "history": history.history
    })
    min_val_mse = min(history.history["val_mse"])
    best_scores.append({
        "layers": exp["layers_count"],
        "units": exp["hidden_units"],
        "activation": exp["activation"],
        "dropout": exp["use_dropout"],
        "min_val_mse": min_val_mse
    })

# Визуализация: только MSE, 2x2 графика
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, result in enumerate(results):
    params = result["params"]
    history = result["history"]
    
    # Подробный заголовок для графика
    title = (
        f"{params['layers_count']} layers, "
        f"{params['hidden_units']} units, "
        f"activation: {params['activation']}, "
        f"Dropout: {'Yes' if params['use_dropout'] else 'No'}"
    )

    axes[i].plot(history["mse"], label="Train MSE", linestyle='-')
    axes[i].plot(history["val_mse"], label="Validation MSE", linestyle='-.')
    axes[i].set_title(title, fontsize=16)  # Увеличенный шрифт заголовка
    axes[i].legend(fontsize=14)            # Увеличенный шрифт легенды
    axes[i].grid(True)

plt.tight_layout()
plt.savefig('Gr_MSE_COVID_UVELICH.png')
plt.show()

# Таблица лучших результатов
print("\nСравнение моделей Covid-19 по минимальному значению MSE на валидации:")
for score in best_scores:
    print(f"Layers: {score['layers']}, Units: {score['units']}, Activation: {score['activation']}, Dropout: {score['dropout']} → "
          f"Min Val MSE: {score['min_val_mse']:.6f}")
# Out:
# Тренируем модель: 2 слоя(ев), 128 нейронов, активация relu, Dropout: False...
# Epoch 1/20
# C:\Users\HONOR\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0478 - mse: 0.0478 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0071 - val_mse: 0.0071
# Тренируем модель: 5 слоя(ев), 128 нейронов, активация relu, Dropout: True...
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0114 - val_mse: 0.0114
# Тренируем модель: 2 слоя(ев), 64 нейронов, активация tanh, Dropout: False...
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0465 - mse: 0.0465 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0072 - val_mse: 0.0072
# Тренируем модель: 5 слоя(ев), 64 нейронов, активация tanh, Dropout: True...
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - loss: 0.0458 - mse: 0.0458 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0084 - val_mse: 0.0084
# Сравнение моделей Covid-19 по минимальному значению MSE на валидации:
# Layers: 2, Units: 128, Activation: relu, Dropout: False → Min Val MSE: 0.006982
# Layers: 5, Units: 128, Activation: relu, Dropout: True → Min Val MSE: 0.010082
# Layers: 2, Units: 64, Activation: tanh, Dropout: False → Min Val MSE: 0.007121
# Layers: 5, Units: 64, Activation: tanh, Dropout: True → Min Val MSE: 0.008438
