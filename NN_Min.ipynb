# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_series(file_path, title, time_col='timestamp', value_col='value'):
    df = pd.read_csv(file_path)
    df.columns = [col.lower() for col in df.columns]
    
    # Ограничим число точек для наглядности
    df = df.head(1000)
    df[time_col] = pd.to_datetime(df[time_col])
    
    plt.figure(figsize=(8, 4))
    plt.plot(df[time_col], df[value_col], color='steelblue')
    plt.title(title)
    plt.xlabel('Время')
    plt.ylabel('Значение')
    plt.grid(True)
    
    # Форматируем дату как "месяц-день"
    date_format = mdates.DateFormatter('%Y-%m-%d')
    plt.gca().xaxis.set_major_formatter(date_format)
    plt.xticks(rotation=20)
    
    plt.tight_layout()
    plt.savefig('graf_ART.png')
    plt.show()

plot_series('TIMES/daily-min-temperatures.csv', 'Минимальные температуры (сезонность и слабый тренд)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Функция для построения одного графика
def plot_series(file_path, title, time_col='timestamp', value_col='value'):
    df = pd.read_csv(file_path)
    df.columns = [col.lower() for col in df.columns]  # Приведение к нижнему регистру
    plt.figure(figsize=(10, 4))
    plt.plot(pd.to_datetime(df[time_col]), df[value_col], color='steelblue')
    plt.title(title)
    plt.xlabel('Время')
    plt.ylabel('Значение')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('graf_MIN.png')
    plt.show()

# Построение каждого ряда по отдельности
plot_series('TIMES/daily-min-temperatures.csv', 'Минимальные температуры (сезонность и слабый тренд)')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.layers import Input

# 1. Загрузка данных из файла
file_path = "TIMES/daily-min-temperatures.csv"
df = pd.read_csv(file_path)

# Проверяем содержимое файла
print(df.head())

# Преобразование timestamp в формат datetime и установка индекса
df["timestamp"] = pd.to_datetime(df["timestamp"], format="%Y-%m-%d") # Указываем формат времени
df.set_index("timestamp", inplace=True)

# 2. Подготовка данных
# Ресемплинг данных, если необходимо (например, для равномерного временного ряда)
#df = df.resample("5min").mean() #Удаляем! Не нужен, данные дневные.

# Масштабирование значений в диапазон [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
df["value"] = scaler.fit_transform(df[["value"]])

# Создание входных (X) и выходных (y) последовательностей
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i : i + seq_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)

sequence_length = 30  # Длина входной последовательности, 30 дней. Учитываем месячный цикл.
data_values = df["value"].values
X, y = create_sequences(data_values, sequence_length)


test_size = 0.2  # 20% для тестового набора
test_split_idx = int(len(data_values) * (1 - test_size))

X_train, X_test = X[:test_split_idx], X[test_split_idx:]
y_train, y_test = y[:test_split_idx], y[test_split_idx:]


# Преобразование данных в 3D-формат для LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# 3. Построение модели LSTM
model = Sequential()
model.add(Input(shape=(sequence_length, 1)))  # Явно задаем вход
model.add(LSTM(50, activation="relu"))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mse")

# 4. Обучение модели
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# 5. Прогнозирование
y_pred = model.predict(X_test)

# Обратное масштабирование для оценки
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# Визуализация
plt.figure(figsize=(10, 6))
plt.plot(y_test, label="Истинные значения")
plt.plot(y_pred, label="Прогноз", linestyle="dashed")
plt.legend()
plt.title("Прогнозирование daily-min-temperatures.csv с использованием LSTM")
plt.savefig('progn_Min.png')
plt.show()

# Сохранение модели
model.save("lstm_model.keras")
# Out:
#     timestamp  value
# 0  1981-01-01   20.7
# 1  1981-01-02   17.9
# 2  1981-01-03   18.8
# 3  1981-01-04   14.6
# 4  1981-01-05   15.8
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0680 - val_loss: 0.0094
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0114 - val_loss: 0.0092
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0107 - val_loss: 0.0091
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - val_loss: 0.0087
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0110 - val_loss: 0.0088
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0100 - val_loss: 0.0083
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0099 - val_loss: 0.0079
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - val_loss: 0.0079
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0095 - val_loss: 0.0087
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - val_loss: 0.0073
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0096 - val_loss: 0.0074
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0091 - val_loss: 0.0071
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0093 - val_loss: 0.0073
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0072
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0086 - val_loss: 0.0071
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0092 - val_loss: 0.0074
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0071
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0090 - val_loss: 0.0077
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0093 - val_loss: 0.0071
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0071
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0090 - val_loss: 0.0071
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - val_loss: 0.0071
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - val_loss: 0.0071
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0071
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0087 - val_loss: 0.0070
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - val_loss: 0.0072
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094 - val_loss: 0.0071
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0071
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0092 - val_loss: 0.0071
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - val_loss: 0.0070
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0087 - val_loss: 0.0070
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - val_loss: 0.0083
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0072
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - val_loss: 0.0070
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - val_loss: 0.0071
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0070
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0070
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - val_loss: 0.0072
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - val_loss: 0.0075
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Построение графика потерь (Loss)
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss', linestyle='-')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='-.')
plt.title("График потерь по эпохам daily-min-temperatures.csv")
plt.xlabel("Эпоха")
plt.ylabel("MSE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("loss_Min.png")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam

# Загрузка данных
df = pd.read_csv("TIMES/daily-min-temperatures.csv")
df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d")
df.set_index('timestamp', inplace=True)
#df = df.resample("5T").mean()  # Агрегация по 5 минутам - удаляем

# Нормализация данных
data_min = df['value'].min()
data_max = df['value'].max()
df['value'] = (df['value'] - data_min) / (data_max - data_min)

# Подготовка данных
sequence_length = 30 # Длина последовательности
data = df['value'].values
X, y = [], []

for i in range(len(data) - sequence_length):
    X.append(data[i:i + sequence_length])
    y.append(data[i + sequence_length])

X = np.array(X)
y = np.array(y)

# Разделение на обучающую и тестовую выборки
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Функция для создания модели
def create_model(layers_count, hidden_units, activation, use_dropout):
    model = Sequential()
    model.add(LSTM(hidden_units, activation=activation, input_shape=(sequence_length, 1), return_sequences=(layers_count > 1)))
    for _ in range(layers_count - 1):
        model.add(LSTM(hidden_units, activation=activation, return_sequences=False if _ == layers_count - 2 else True))
        if use_dropout:
            model.add(Dropout(0.2))  # Регуляризация Dropout
    model.add(Dense(1))  # Выходной слой
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse'])
    return model

# Экспериментальные настройки
experiments = [
    {"layers_count": 2, "hidden_units": 128, "activation": "relu", "use_dropout": False},
    {"layers_count": 5, "hidden_units": 128, "activation": "relu", "use_dropout": True},
    {"layers_count": 2, "hidden_units": 64, "activation": "tanh", "use_dropout": False},
    {"layers_count": 5, "hidden_units": 64, "activation": "tanh", "use_dropout": True},
]

results = []
best_scores = []

# Обучение моделей
for exp in experiments:
    print(f"Тренируем модель: {exp['layers_count']} слоя(ев), {exp['hidden_units']} нейронов, активация {exp['activation']}, Dropout: {exp['use_dropout']}...")
    model = create_model(exp["layers_count"], exp["hidden_units"], exp["activation"], exp["use_dropout"])
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        batch_size=32,
        epochs=20,
        verbose=1
    )
    results.append({
        "params": exp,
        "history": history.history
    })
    min_val_mse = min(history.history["val_mse"])
    best_scores.append({
        "layers": exp["layers_count"],
        "units": exp["hidden_units"],
        "activation": exp["activation"],
        "dropout": exp["use_dropout"],
        "min_val_mse": min_val_mse
    })

# Визуализация: только MSE, 2x2 графика
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, result in enumerate(results):
    params = result["params"]
    history = result["history"]
    
    # Подробный заголовок для графика
    title = (
        f"{params['layers_count']} layers, "
        f"{params['hidden_units']} units, "
        f"activation: {params['activation']}, "
        f"Dropout: {'Yes' if params['use_dropout'] else 'No'}"
    )
    axes[i].plot(history["mse"], label="Train MSE", linestyle='-')
    axes[i].plot(history["val_mse"], label="Validation MSE", linestyle='-.')
    axes[i].set_title(title, fontsize=16)  # Увеличенный шрифт заголовка
    axes[i].legend(fontsize=14)            # Увеличенный шрифт легенды
    axes[i].grid(True)

plt.tight_layout()
plt.savefig('Gr_MSE_MIN_UVELICH.png')
plt.show()

# Таблица лучших результатов
print("\nСравнение моделей MIN по минимальному значению MSE на валидации:")
for score in best_scores:
    print(f"Layers: {score['layers']}, Units: {score['units']}, Activation: {score['activation']}, Dropout: {score['dropout']} → "
          f"Min Val MSE: {score['min_val_mse']:.6f}")
# Out:
# Тренируем модель: 2 слоя(ев), 128 нейронов, активация relu, Dropout: False...
# Epoch 1/20
# C:\Users\HONOR\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0074 - val_mse: 0.0074
# Тренируем модель: 5 слоя(ев), 128 нейронов, активация relu, Dropout: True...
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - loss: 0.0510 - mse: 0.0510 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0107 - val_mse: 0.0107
# Тренируем модель: 2 слоя(ев), 64 нейронов, активация tanh, Dropout: False...
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0347 - mse: 0.0347 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0070 - val_mse: 0.0070
# Тренируем модель: 5 слоя(ев), 64 нейронов, активация tanh, Dropout: True...
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 11s 41ms/step - loss: 0.0387 - mse: 0.0387 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0080 - val_mse: 0.0080
# Сравнение моделей MIN по минимальному значению MSE на валидации:
# Layers: 2, Units: 128, Activation: relu, Dropout: False → Min Val MSE: 0.007226
# Layers: 5, Units: 128, Activation: relu, Dropout: True → Min Val MSE: 0.010101
# Layers: 2, Units: 64, Activation: tanh, Dropout: False → Min Val MSE: 0.007029
# Layers: 5, Units: 64, Activation: tanh, Dropout: True → Min Val MSE: 0.007613
