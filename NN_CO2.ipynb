# %%
import pandas as pd
import matplotlib.pyplot as plt

# Функция для построения одного графика
def plot_series(file_path, title, time_col='timestamp', value_col='value'):
    df = pd.read_csv(file_path)
    df.columns = [col.lower() for col in df.columns]  # Приведение к нижнему регистру
    df = df.head(100)
    df[time_col] = pd.to_datetime(df[time_col])
    plt.figure(figsize=(7, 3))
    plt.plot(pd.to_datetime(df[time_col]), df[value_col], color='steelblue')
    plt.title(title)
    plt.xlabel('Время')
    plt.ylabel('Значение')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('graf_CO2.png')
    plt.show()

# Построение каждого ряда по отдельности
plot_series('TIMES/co2_clean.csv', 'Уровень CO2 (тренд и сезонность)')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.layers import Input

# 1. Загрузка данных из файла
file_path = "TIMES/co2_clean.csv"
df = pd.read_csv(file_path)

# Проверяем содержимое файла
print(df.head())

# Преобразование timestamp в формат datetime и установка индекса
df["timestamp"] = pd.to_datetime(df["timestamp"], format="%Y-%m") # Указываем формат времени
df.set_index("timestamp", inplace=True)

# Масштабирование значений в диапазон [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
df["value"] = scaler.fit_transform(df[["value"]])

# Создание входных (X) и выходных (y) последовательностей
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i : i + seq_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)

sequence_length = 12  # Длина входной последовательности, 12 месяцев в году.  Важно для сезонности.
data_values = df["value"].values
X, y = create_sequences(data_values, sequence_length)


test_size = 0.2  # 20% для тестового набора
test_split_idx = int(len(data_values) * (1 - test_size))

X_train, X_test = X[:test_split_idx], X[test_split_idx:]
y_train, y_test = y[:test_split_idx], y[test_split_idx:]


# Преобразование данных в 3D-формат для LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# 3. Построение модели LSTM
model = Sequential()
model.add(Input(shape=(sequence_length, 1)))  # Явно задаем вход
model.add(LSTM(50, activation="relu"))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mse")

# 4. Обучение модели
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# 5. Прогнозирование
y_pred = model.predict(X_test)

# Обратное масштабирование для оценки
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# Визуализация
plt.figure(figsize=(10, 6))
plt.plot(y_test, label="Истинные значения")
plt.plot(y_pred, label="Прогноз", linestyle="dashed")
plt.legend()
plt.title("Прогнозирование co2_clean_deseasonalized с использованием LSTM")
plt.savefig('progn_CO2_deseasonalized.png')
plt.show()


# Сохранение модели
model.save("lstm_model.keras")
# Out:
#   timestamp   value
# 0   1958-03  315.71
# 1   1958-04  317.45
# 2   1958-05  317.51
# 3   1958-06  317.27
# 4   1958-07  315.87
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1062 - val_loss: 0.2172
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - val_loss: 0.0064
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - val_loss: 0.0061
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6010e-04 - val_loss: 0.0092
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3940e-04 - val_loss: 0.0067
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5641e-04 - val_loss: 0.0042
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2908e-04 - val_loss: 0.0018
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7282e-04 - val_loss: 0.0020
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0708e-04 - val_loss: 0.0024
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8184e-04 - val_loss: 0.0018
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9565e-04 - val_loss: 0.0021
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1577e-04 - val_loss: 0.0021
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9916e-04 - val_loss: 0.0016
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0108e-04 - val_loss: 0.0021
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8138e-04 - val_loss: 0.0013
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3794e-04 - val_loss: 0.0017
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7882e-04 - val_loss: 0.0014
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5857e-04 - val_loss: 0.0025
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2063e-04 - val_loss: 0.0010
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8482e-04 - val_loss: 0.0014
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0609e-04 - val_loss: 0.0013
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0305e-04 - val_loss: 0.0010
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9787e-04 - val_loss: 0.0012
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8019e-04 - val_loss: 9.2347e-04
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7419e-04 - val_loss: 0.0011
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8214e-04 - val_loss: 0.0010
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6619e-04 - val_loss: 0.0014
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6759e-04 - val_loss: 0.0012
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6103e-04 - val_loss: 9.7434e-04
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6609e-04 - val_loss: 0.0010
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6521e-04 - val_loss: 5.8277e-04
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9371e-04 - val_loss: 0.0012
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4674e-04 - val_loss: 0.0014
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6242e-04 - val_loss: 0.0013
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5882e-04 - val_loss: 8.8786e-04
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5920e-04 - val_loss: 0.0012
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2030e-04 - val_loss: 0.0012
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7159e-04 - val_loss: 0.0021
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4715e-04 - val_loss: 0.0010
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4194e-04 - val_loss: 0.0023
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6196e-04 - val_loss: 0.0013
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5675e-04 - val_loss: 0.0013
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2437e-04 - val_loss: 7.8010e-04
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1896e-04 - val_loss: 0.0015
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4387e-04 - val_loss: 7.7868e-04
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3991e-04 - val_loss: 0.0016
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1353e-04 - val_loss: 0.0011
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0265e-04 - val_loss: 0.0011
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1751e-04 - val_loss: 0.0015
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1184e-04 - val_loss: 0.0016
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
# Построение графика потерь (Loss)
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss', linestyle='-')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='-.')
plt.title("График потерь (СO2) по эпохам")
plt.xlabel("Эпоха")
plt.ylabel("MSE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('loss_CO2.png')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam

# Загрузка данных
df = pd.read_csv("TIMES/co2_clean.csv")
df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m") # Указываем формат года и месяца
df.set_index('timestamp', inplace=True)
# df = df.resample("5T").mean()  # Агрегация по 5 минутам - УДАЛЯЕМ! Не нужен, данные месячные.
# df = df.resample("M").mean() #Если есть пропущенные месяцы раскомментировать

# Нормализация данных
data_min = df['value'].min()
data_max = df['value'].max()
df['value'] = (df['value'] - data_min) / (data_max - data_min)

# Подготовка данных
sequence_length = 12  #  12 месяцев - разумная длина последовательности
data = df['value'].values
X, y = [], []

for i in range(len(data) - sequence_length):
    X.append(data[i:i + sequence_length])
    y.append(data[i + sequence_length])

X = np.array(X)
y = np.array(y)

# Разделение на обучающую и тестовую выборки
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Функция для создания модели
def create_model(layers_count, hidden_units, activation, use_dropout):
    model = Sequential()
    model.add(LSTM(hidden_units, activation=activation, input_shape=(sequence_length, 1), return_sequences=(layers_count > 1)))
    for _ in range(layers_count - 1):
        model.add(LSTM(hidden_units, activation=activation, return_sequences=False if _ == layers_count - 2 else True))
        if use_dropout:
            model.add(Dropout(0.2))  # Регуляризация Dropout
    model.add(Dense(1))  # Выходной слой
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse'])
    return model

# Экспериментальные настройки
experiments = [
    {"layers_count": 2, "hidden_units": 128, "activation": "relu", "use_dropout": False},
    {"layers_count": 5, "hidden_units": 128, "activation": "relu", "use_dropout": True},
    {"layers_count": 2, "hidden_units": 64, "activation": "tanh", "use_dropout": False},
    {"layers_count": 5, "hidden_units": 64, "activation": "tanh", "use_dropout": True},
]

results = []
best_scores = []

# Обучение моделей
for exp in experiments:
    print(f"Тренируем модель: {exp['layers_count']} слоя(ев), {exp['hidden_units']} нейронов, активация {exp['activation']}, Dropout: {exp['use_dropout']}...")
    model = create_model(exp["layers_count"], exp["hidden_units"], exp["activation"], exp["use_dropout"])
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        batch_size=32,
        epochs=20,
        verbose=1
    )
    results.append({
        "params": exp,
        "history": history.history
    })
    min_val_mse = min(history.history["val_mse"])
    best_scores.append({
        "layers": exp["layers_count"],
        "units": exp["hidden_units"],
        "activation": exp["activation"],
        "dropout": exp["use_dropout"],
        "min_val_mse": min_val_mse
    })

# Визуализация: только MSE, 2x2 графика
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, result in enumerate(results):
    params = result["params"]
    history = result["history"]
    
    # Подробный заголовок для графика
    title = (
        f"{params['layers_count']} layers, "
        f"{params['hidden_units']} units, "
        f"activation: {params['activation']}, "
        f"Dropout: {'Yes' if params['use_dropout'] else 'No'}"
    )

    axes[i].plot(history["mse"], label="Train MSE", linestyle='-')
    axes[i].plot(history["val_mse"], label="Validation MSE", linestyle='-.')
    axes[i].set_title(title, fontsize=16)  # Увеличенный шрифт заголовка
    axes[i].legend(fontsize=14)            # Увеличенный шрифт легенды
    axes[i].grid(True)


plt.tight_layout()
plt.savefig('Gr_MSE_CO2_UVELICH.png')
plt.show()

# Таблица лучших результатов
print("\nСравнение моделей CO2 по минимальному значению MSE на валидации:")
for score in best_scores:
    print(f"Layers: {score['layers']}, Units: {score['units']}, Activation: {score['activation']}, Dropout: {score['dropout']} → "
          f"Min Val MSE: {score['min_val_mse']:.6f}")
# Out:
# Тренируем модель: 2 слоя(ев), 128 нейронов, активация relu, Dropout: False...
# Epoch 1/20
# C:\Users\HONOR\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.0946 - mse: 0.0946 - val_loss: 0.0277 - val_mse: 0.0277
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.7024e-04 - mse: 9.7024e-04 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7462e-04 - mse: 4.7462e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2298e-04 - mse: 4.2298e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4523e-04 - mse: 4.4523e-04 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1452e-04 - mse: 4.1452e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2705e-04 - mse: 4.2705e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2354e-04 - mse: 4.2354e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0145e-04 - mse: 4.0145e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2637e-04 - mse: 4.2637e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9836e-04 - mse: 3.9836e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1132e-04 - mse: 4.1132e-04 - val_loss: 8.1758e-04 - val_mse: 8.1758e-04
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3535e-04 - mse: 4.3535e-04 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7494e-04 - mse: 3.7494e-04 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8711e-04 - mse: 3.8711e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7609e-04 - mse: 4.7609e-04 - val_loss: 6.4669e-04 - val_mse: 6.4669e-04
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1066e-04 - mse: 5.1066e-04 - val_loss: 6.9932e-04 - val_mse: 6.9932e-04
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3069e-04 - mse: 4.3069e-04 - val_loss: 6.2744e-04 - val_mse: 6.2744e-04
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9601e-04 - mse: 3.9601e-04 - val_loss: 6.6596e-04 - val_mse: 6.6596e-04
# Тренируем модель: 5 слоя(ев), 128 нейронов, активация relu, Dropout: True...
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - loss: 0.0932 - mse: 0.0932 - val_loss: 0.1623 - val_mse: 0.1623
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.1421 - val_mse: 0.1421
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 9.7676e-04 - val_mse: 9.7676e-04
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 6.8523e-04 - val_mse: 6.8523e-04
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 4.3841e-04 - val_mse: 4.3841e-04
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 4.3317e-04 - val_mse: 4.3317e-04
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 4.8091e-04 - val_mse: 4.8091e-04
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 3.2770e-04 - val_mse: 3.2770e-04
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 3.3654e-04 - val_mse: 3.3654e-04
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 9.6327e-04 - val_mse: 9.6327e-04
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0059 - val_mse: 0.0059
# Тренируем модель: 2 слоя(ев), 64 нейронов, активация tanh, Dropout: False...
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0543 - val_mse: 0.0543
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2472e-04 - mse: 8.2472e-04 - val_loss: 7.2298e-04 - val_mse: 7.2298e-04
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7850e-04 - mse: 4.7850e-04 - val_loss: 5.6874e-04 - val_mse: 5.6874e-04
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7038e-04 - mse: 4.7038e-04 - val_loss: 5.2449e-04 - val_mse: 5.2449e-04
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9947e-04 - mse: 4.9947e-04 - val_loss: 4.9493e-04 - val_mse: 4.9493e-04
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7262e-04 - mse: 4.7262e-04 - val_loss: 4.9335e-04 - val_mse: 4.9335e-04
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7017e-04 - mse: 4.7017e-04 - val_loss: 6.1321e-04 - val_mse: 6.1321e-04
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5155e-04 - mse: 4.5155e-04 - val_loss: 5.3795e-04 - val_mse: 5.3795e-04
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3626e-04 - mse: 4.3626e-04 - val_loss: 4.9090e-04 - val_mse: 4.9090e-04
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5599e-04 - mse: 4.5599e-04 - val_loss: 5.6862e-04 - val_mse: 5.6862e-04
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6836e-04 - mse: 4.6836e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4982e-04 - mse: 4.4982e-04 - val_loss: 4.9716e-04 - val_mse: 4.9716e-04
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5993e-04 - mse: 4.5993e-04 - val_loss: 5.0095e-04 - val_mse: 5.0095e-04
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6353e-04 - mse: 4.6353e-04 - val_loss: 7.4782e-04 - val_mse: 7.4782e-04
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3660e-04 - mse: 4.3660e-04 - val_loss: 6.7915e-04 - val_mse: 6.7915e-04
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3025e-04 - mse: 4.3025e-04 - val_loss: 6.1642e-04 - val_mse: 6.1642e-04
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3090e-04 - mse: 4.3090e-04 - val_loss: 9.3776e-04 - val_mse: 9.3776e-04
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2164e-04 - mse: 4.2164e-04 - val_loss: 6.7280e-04 - val_mse: 6.7280e-04
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3015e-04 - mse: 4.3015e-04 - val_loss: 8.7306e-04 - val_mse: 8.7306e-04
# Тренируем модель: 5 слоя(ев), 64 нейронов, активация tanh, Dropout: True...
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - loss: 0.0755 - mse: 0.0755 - val_loss: 0.1825 - val_mse: 0.1825
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 7.2180e-04 - val_mse: 7.2180e-04
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 6.7363e-04 - val_mse: 6.7363e-04
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 9.5121e-04 - val_mse: 9.5121e-04
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0019 - val_mse: 0.0019
# Сравнение моделей CO2 по минимальному значению MSE на валидации:
# Layers: 2, Units: 128, Activation: relu, Dropout: False → Min Val MSE: 0.000627
# Layers: 5, Units: 128, Activation: relu, Dropout: True → Min Val MSE: 0.000328
# Layers: 2, Units: 64, Activation: tanh, Dropout: False → Min Val MSE: 0.000491
# Layers: 5, Units: 64, Activation: tanh, Dropout: True → Min Val MSE: 0.000674
